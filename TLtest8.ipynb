# %%
import numpy as np # linear algebra
import random
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model, load_model
import keras
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose,AveragePooling2D, MaxPooling2D,UpSampling2D,LeakyReLU, concatenate, Dropout,BatchNormalization,Activation
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import pandas as pd
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from numpy.random import seed
seed(123)
import tensorflow as tf
tf.random.set_seed(123)
from tensorflow.python.keras import backend as K
from tensorflow.keras.models import Sequential
session_conf =  tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)
from skimage.transform import resize
from sklearn.metrics import jaccard_score
from keras import metrics
import segmentation_models as sm
# Out:
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
# ESTABLISHING PATHS
path= (r'C:/Users/k v/Documents/REU/ShorelineDetection/data/')
model_path = (r'C:/Users/k v/Documents/REU/ShorelineDetection/model7/')
result_path = (r'C:/Users/k v/Documents/REU/ShorelineDetection/results/')

# %%
# GRABBING THE TRAIN DATA
def ExtractData(path):
    SourceImg = sorted(os.listdir(path+'train_img'))
    TargetImg = sorted(os.listdir(path+'train_mask'))
   
    X_=[]
    y_=[]
    count=0
    for i in range(len(SourceImg)):
        if count<2165:
            count=count+1
            img_1 = cv2.imread(path+'train_img/'+SourceImg[i])
            img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)  #CV2 READS IMAGES AS BGR, SO TRANSFORM TO RGB
            img_1 = cv2.resize(img_1,(500,500))
            img_1 = img_1/255.0  #NORMALIZE DATA
            X_.append(img_1)
            img_2 = cv2.imread(path+'train_mask/'+TargetImg[i])
            img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
            img_2 = cv2.resize(img_2,(500,500))
            img_2 = img_2/255.0
            y_.append(img_2)
    X_ = np.array(X_)
    y_ = np.array(y_)
    
    return X_,y_

# %%
# EXTRACTING THE DATA
X_,y_ = ExtractData(path)

# %%
# AUGMENTING DATA TO INCREASE DATA FOR TRAINING
def AugmentData(X_, y_):
    X_2=[]
    y_2=[]
    count=0
    for i in range(len(X_)):
        if count<2165:
            count=count+1

            # Augment training images
            #img_x_1 = tf.placeholder(dtype = tf.float32, shape = X_[i])
            temp_x = []
            temp_x_1 = X_[i]
            temp_x_2 = tf.image.flip_up_down(temp_x_1)
            temp_x_3 = tf.image.flip_left_right(temp_x_1)
            temp_x_4 = tf.image.flip_up_down(temp_x_3)
            temp_x_5 = tf.image.rot90(temp_x_1)
            temp_x_6 = tf.image.rot90(temp_x_2)
            temp_x_7 = tf.image.rot90(temp_x_3)
            temp_x_8 = tf.image.rot90(temp_x_4)
            X_2.append(np.array(temp_x_1))
            X_2.append(np.array(temp_x_2))
            X_2.append(np.array(temp_x_3))
            X_2.append(np.array(temp_x_4))
            X_2.append(np.array(temp_x_5))
            X_2.append(np.array(temp_x_6))
            X_2.append(np.array(temp_x_7))
            X_2.append(np.array(temp_x_8))

            # Augment training masks
            # The augmentations here are identicial to their corresponding image counterparts.
            #img_y_1 = tf.placeholder(dtype = tf.float32, shape = y_[i])
            temp_y = []
            temp_y_1 = y_[i]
            temp_y_2 = tf.image.flip_up_down(temp_y_1)
            temp_y_3 = tf.image.flip_left_right(temp_y_1)
            temp_y_4 = tf.image.flip_up_down(temp_y_3)
            temp_y_5 = tf.image.rot90(temp_y_1)
            temp_y_6 = tf.image.rot90(temp_y_2)
            temp_y_7 = tf.image.rot90(temp_y_3)
            temp_y_8 = tf.image.rot90(temp_y_4)
            y_2.append(np.array(temp_y_1))
            y_2.append(np.array(temp_y_2))
            y_2.append(np.array(temp_y_3))
            y_2.append(np.array(temp_y_4))
            y_2.append(np.array(temp_y_5))
            y_2.append(np.array(temp_y_6))
            y_2.append(np.array(temp_y_7))
            y_2.append(np.array(temp_y_8))
    X_2 = np.array(X_2)
    y_2 = np.array(y_2)
    
    return X_2,y_2

# %%
# TRANSFORM IMAGES FORM UINT8 TO FLOAT32
X_ = X_.astype(np.float32)
y_ = y_.astype(np.float32)
# y_ = np.expand_dims(y_, axis=3)

# %%
# AUGMENT DATA
X_,y_ = AugmentData(X_, y_)

# %%
#CHECK SHAPE OF DATA, SIZE OF DATA
print(X_.shape)
print(y_.shape)
# Out:
# (2096, 500, 500, 3)
# (2096, 500, 500, 3)

# %%
# SPLIT TRAINING DATA INTO TEST AND TRAIN 
X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.1, random_state=42)

# %%
# BUILDING THE MODEL WITH IMPLEMENTATION OF TRANSFER LEARNING
input_shape = (500, 500, 3 )
VGG16_weight = "../vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"
VGG16_MODEL=tf.keras.applications.VGG16(input_shape=input_shape,
                                               include_top=False,
                                               weights='imagenet')
VGG16 = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=input_shape)

print('Model loaded.')
# Out:
# Model loaded.

# %%
output_ = VGG16.output
output_
# Out:
# <tf.Tensor 'block5_pool_1/Identity:0' shape=(None, 15, 15, 512) dtype=float32>

# %%
# VISUALIZE THE LAYERS & FREEZE APPROPRIATE LAYERS
set_trainable = False
for layer in VGG16.layers:
    if layer.name in ['block1_conv1']:
        set_trainable = True
    if layer.name in ['block1_pool','block2_pool','block3_pool','block4_pool','block5_pool']:
        layer.trainable = False

# %%
vgg_model = Model(VGG16.input, output_)
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                            Layer Type    Layer Name  \
# 0   <tensorflow.python.keras.engine.input_layer.In...       input_2
# 1   <tensorflow.python.keras.layers.convolutional....  block1_conv1
# 2   <tensorflow.python.keras.layers.convolutional....  block1_conv2
# 3   <tensorflow.python.keras.layers.pooling.MaxPoo...   block1_pool
# 4   <tensorflow.python.keras.layers.convolutional....  block2_conv1
# 5   <tensorflow.python.keras.layers.convolutional....  block2_conv2
# 6   <tensorflow.python.keras.layers.pooling.MaxPoo...   block2_pool
# 7   <tensorflow.python.keras.layers.convolutional....  block3_conv1
# 8   <tensorflow.python.keras.layers.convolutional....  block3_conv2
# 9   <tensorflow.python.keras.layers.convolutional....  block3_conv3
# 10  <tensorflow.python.keras.layers.pooling.MaxPoo...   block3_pool
# 11  <tensorflow.python.keras.layers.convolutional....  block4_conv1
# 12  <tensorflow.python.keras.layers.convolutional....  block4_conv2
# 13  <tensorflow.python.keras.layers.convolutional....  block4_conv3
# 14  <tensorflow.python.keras.layers.pooling.MaxPoo...   block4_pool
# 15  <tensorflow.python.keras.layers.convolutional....  block5_conv1
# 16  <tensorflow.python.keras.layers.convolutional....  block5_conv2
# 17  <tensorflow.python.keras.layers.convolutional....  block5_conv3
# 18  <tensorflow.python.keras.layers.pooling.MaxPoo...   block5_pool
#
#     Layer Trainable
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
# 5              True
# 6             False
# 7              True
# 8              True
# 9              True
# 10            False
# 11             True
# 12             True
# 13             True
# 14            False
# 15             True
# 16             True
# 17             True
# 18            False

# %%
vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 500, 500, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 500, 500, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 500, 500, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 250, 250, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 250, 250, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 250, 250, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 125, 125, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 125, 125, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 125, 125, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 125, 125, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 62, 62, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 62, 62, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 62, 62, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 62, 62, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 31, 31, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 31, 31, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 31, 31, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 31, 31, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 15, 15, 512)       0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
K.clear_session()
def ModelEnhancer():
    input_shape = (500, 500, 3 )
#     VGG16_weight = "../input/keras-pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"
#     VGG16 = vgg16.VGG16(include_top=False, weights=VGG16_weight, input_shape=input_shape)
    VGG16=tf.keras.applications.VGG16( input_shape=input_shape,
                                               include_top=False,
                                               weights='imagenet')
    last_layer = VGG16.output
    
    set_trainable = False
    for layer in VGG16.layers:
        if layer.name in ['block1_conv1']:
            set_trainable = True
        if layer.name in ['block1_pool','block2_pool','block3_pool','block4_pool','block5_pool']:
            layer.trainable = False
   
    model_ = Conv2DTranspose(256,(3,3),strides=(2, 2))(last_layer)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)    
    
    concat_1 = concatenate([model_,VGG16.get_layer("block5_conv3").output])
    
    model_ = Conv2D(512,(3,3),strides=(1, 1),padding='same')(concat_1)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Conv2DTranspose(512,(3,3),strides=(2, 2),padding='same')(model_)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_) 
    
    concat_2 = concatenate([model_,VGG16.get_layer("block4_conv3").output])
    
    model_ = Conv2D(512,(3,3),strides=(1, 1),padding='same')(concat_2)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Conv2DTranspose(512,(3,3),strides=(2, 2))(model_)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_) 
    
    concat_3 = concatenate([model_,VGG16.get_layer("block3_conv3").output])
    
    model_ = Conv2D(256,(3,3),strides=(1, 1),padding='same')(concat_3)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Conv2DTranspose(256,(3,3),strides=(2, 2),padding='same')(model_)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_) 
    
    concat_4 = concatenate([model_,VGG16.get_layer("block2_conv2").output])
    
    model_ = Conv2D(128,(3,3),strides=(1, 1),padding='same')(concat_4)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Conv2DTranspose(128,(3,3),strides=(2, 2),padding='same')(model_)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_) 
    
    concat_5 = concatenate([model_,VGG16.get_layer("block1_conv2").output])
    
    model_ = Conv2D(64,(3,3),strides=(1, 1),padding='same')(concat_5)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Conv2D(32,(3,3),strides=(1, 1),padding='same')(model_)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Conv2D(3,(3,3),strides=(1, 1),padding='same')(model_)
    model_ = LeakyReLU(0.1)(model_)
    model_ = BatchNormalization()(model_)
    
    model_ = Model(VGG16.input,model_)
    
    return model_

# %%
Model_ = ModelEnhancer()
Model_.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 500, 500, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 500, 500, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 500, 500, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 250, 250, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 250, 250, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 250, 250, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 125, 125, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 125, 125, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 125, 125, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 125, 125, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 62, 62, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 62, 62, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 62, 62, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 62, 62, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 31, 31, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 31, 31, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 31, 31, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 31, 31, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 15, 15, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 31, 31, 256)  1179904     block5_pool[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 31, 31, 256)  0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 31, 31, 256)  1024        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 31, 31, 768)  0           batch_normalization[0][0]
#                                                                  block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 31, 31, 512)  3539456     concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 31, 31, 512)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 31, 31, 512)  2048        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 62, 62, 512)  2359808     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 62, 62, 512)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 62, 62, 512)  2048        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 62, 62, 1024) 0           batch_normalization_2[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 62, 62, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 62, 62, 512)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 62, 62, 512)  2048        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 125, 125, 512 2359808     batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 125, 125, 512 0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 125, 125, 512 2048        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 125, 125, 768 0           batch_normalization_4[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 125, 125, 256 1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 125, 125, 256 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 125, 125, 256 1024        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 250, 250, 256 590080      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 250, 250, 256 0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 250, 250, 256 1024        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 250, 250, 384 0           batch_normalization_6[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 250, 250, 128 442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 250, 250, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 250, 250, 128 512         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 500, 500, 128 147584      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 500, 500, 128 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 500, 500, 128 512         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 500, 500, 192 0           batch_normalization_8[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 500, 500, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 500, 500, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 500, 500, 64) 256         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 500, 500, 32) 18464       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 500, 500, 32) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 500, 500, 32) 128         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 500, 500, 3)  867         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 500, 500, 3)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 500, 500, 3)  12          leaky_re_lu_11[0][0]
# ==================================================================================================
# Total params: 31,965,327
# Trainable params: 31,958,985
# Non-trainable params: 6,342
# __________________________________________________________________________________________________

# %%
iou_score = sm.metrics.IOUScore()
metrics = [sm.metrics.IOUScore(), 'accuracy', sm.metrics.FScore()]
Model_.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = metrics)
#Adam(lr = 1e-4)

# %%
checkpointer = ModelCheckpoint(model_path+'model_TL_UNET.h5', verbose=1, mode='auto', monitor='loss',save_best_only=True)

# %%
def GenerateInputs(X,y):
    for i in range(len(X)):
        X_input = X[i].reshape(1,500,500,3)
        y_input = y[i].reshape(1,500,500,3)
        yield (X_input,y_input)
results = Model_.fit(GenerateInputs(X_train,y_train), epochs=500, validation_data=(X_test,y_test), verbose=1, callbacks=[checkpointer], steps_per_epoch=2,
                     shuffle=True)
# results = Model_.fit(X_train, y_train, epochs=5, validation_data=(X_test,y_test), verbose=1, callbacks=[checkpointer], steps_per_epoch=2,
#                      shuffle=True)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2 steps, validate on 210 samples
# Epoch 1/500
# 1/2 [==============>...............] - ETA: 11s - loss: 3.2471 - iou_score: 0.0177 - accuracy: 0.5490 - f1-score: 0.0342
# Epoch 00001: loss improved from inf to 2.92651, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 27s 14s/step - loss: 2.9265 - iou_score: 0.1796 - accuracy: 0.5620 - f1-score: 0.2266 - val_loss: 9.7779 - val_iou_score: 0.0365 - val_accuracy: 0.1673 - val_f1-score: 0.0141
# Epoch 2/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.9197 - iou_score: 0.1257 - accuracy: 0.5606 - f1-score: 0.2100
# Epoch 00002: loss did not improve from 2.92651
# 2/2 [==============================] - 14s 7s/step - loss: 2.9361 - iou_score: 0.1373 - accuracy: 0.5619 - f1-score: 0.2210 - val_loss: 9.7974 - val_iou_score: 0.0077 - val_accuracy: 0.1682 - val_f1-score: -0.0915
# Epoch 3/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.7536 - iou_score: 0.3108 - accuracy: 0.5882 - f1-score: 0.4208
# Epoch 00003: loss improved from 2.92651 to 2.67038, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 2.6704 - iou_score: 0.3136 - accuracy: 0.5836 - f1-score: 0.4238 - val_loss: 9.7869 - val_iou_score: -0.1009 - val_accuracy: 0.1691 - val_f1-score: -2.4732
# Epoch 4/500
# 1/2 [==============>...............] - ETA: 0s - loss: 3.0597 - iou_score: 0.1282 - accuracy: 0.5600 - f1-score: 0.2095
# Epoch 00004: loss did not improve from 2.67038
# 2/2 [==============================] - 14s 7s/step - loss: 2.8046 - iou_score: 0.2462 - accuracy: 0.5719 - f1-score: 0.3371 - val_loss: 9.6065 - val_iou_score: -0.0851 - val_accuracy: 0.1723 - val_f1-score: -0.2030
# Epoch 5/500
# 1/2 [==============>...............] - ETA: 0s - loss: 3.0033 - iou_score: 0.1691 - accuracy: 0.5616 - f1-score: 0.2698
# Epoch 00005: loss did not improve from 2.67038
# 2/2 [==============================] - 14s 7s/step - loss: 2.7451 - iou_score: 0.2781 - accuracy: 0.5815 - f1-score: 0.3792 - val_loss: 9.2790 - val_iou_score: -0.4915 - val_accuracy: 0.1770 - val_f1-score: -0.9708
# Epoch 6/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.5894 - iou_score: 0.2635 - accuracy: 0.5945 - f1-score: 0.3772
# Epoch 00006: loss improved from 2.67038 to 2.50900, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 2.5090 - iou_score: 0.3208 - accuracy: 0.5935 - f1-score: 0.4296 - val_loss: 8.8933 - val_iou_score: -0.3110 - val_accuracy: 0.1846 - val_f1-score: -0.4782
# Epoch 7/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.3697 - iou_score: 0.4665 - accuracy: 0.5921 - f1-score: 0.5374
# Epoch 00007: loss did not improve from 2.50900
# 2/2 [==============================] - 14s 7s/step - loss: 2.5955 - iou_score: 0.3569 - accuracy: 0.5823 - f1-score: 0.4490 - val_loss: 8.4853 - val_iou_score: -0.1789 - val_accuracy: 0.1961 - val_f1-score: -14.3830
# Epoch 8/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.4386 - iou_score: 0.3776 - accuracy: 0.6035 - f1-score: 0.4820
# Epoch 00008: loss did not improve from 2.50900
# 2/2 [==============================] - 14s 7s/step - loss: 2.6144 - iou_score: 0.3370 - accuracy: 0.5898 - f1-score: 0.4461 - val_loss: 7.9985 - val_iou_score: -0.3380 - val_accuracy: 0.2118 - val_f1-score: 0.3627
# Epoch 9/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.3155 - iou_score: 0.6052 - accuracy: 0.5955 - f1-score: 0.6167
# Epoch 00009: loss did not improve from 2.50900
# 2/2 [==============================] - 14s 7s/step - loss: 2.5224 - iou_score: 0.4656 - accuracy: 0.5854 - f1-score: 0.5264 - val_loss: 7.6123 - val_iou_score: -0.4892 - val_accuracy: 0.2268 - val_f1-score: -0.6715
# Epoch 10/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6889 - iou_score: 0.3643 - accuracy: 0.5812 - f1-score: 0.4663
# Epoch 00010: loss did not improve from 2.50900
# 2/2 [==============================] - 14s 7s/step - loss: 2.6014 - iou_score: 0.5982 - accuracy: 0.5866 - f1-score: 0.6006 - val_loss: 7.4816 - val_iou_score: -0.8052 - val_accuracy: 0.2334 - val_f1-score: -8.4658
# Epoch 11/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2568 - iou_score: 0.4088 - accuracy: 0.6100 - f1-score: 0.5046
# Epoch 00011: loss improved from 2.50900 to 2.43394, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 2.4339 - iou_score: 0.3938 - accuracy: 0.5947 - f1-score: 0.4901 - val_loss: 7.3691 - val_iou_score: 0.8843 - val_accuracy: 0.2418 - val_f1-score: 2.0345
# Epoch 12/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.4392 - iou_score: 0.3041 - accuracy: 0.5955 - f1-score: 0.4177
# Epoch 00012: loss improved from 2.43394 to 2.24838, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 2.2484 - iou_score: 0.4221 - accuracy: 0.6055 - f1-score: 0.5072 - val_loss: 7.2527 - val_iou_score: -2.1392 - val_accuracy: 0.2536 - val_f1-score: 1.0028
# Epoch 13/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2850 - iou_score: 24.2178 - accuracy: 0.5919 - f1-score: 0.8063
# Epoch 00013: loss did not improve from 2.24838
# 2/2 [==============================] - 14s 7s/step - loss: 2.4300 - iou_score: 12.2731 - accuracy: 0.5866 - f1-score: 0.6231 - val_loss: 7.1306 - val_iou_score: -1.1050 - val_accuracy: 0.2666 - val_f1-score: 0.7831
# Epoch 14/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1133 - iou_score: 0.4236 - accuracy: 0.6170 - f1-score: 0.5156
# Epoch 00014: loss improved from 2.24838 to 2.10671, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 2.1067 - iou_score: 0.3935 - accuracy: 0.6085 - f1-score: 0.4906 - val_loss: 7.1053 - val_iou_score: -0.3799 - val_accuracy: 0.2720 - val_f1-score: 0.7285
# Epoch 15/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.0877 - iou_score: 1.2332 - accuracy: 0.5987 - f1-score: 0.8037
# Epoch 00015: loss improved from 2.10671 to 2.02611, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 2.0261 - iou_score: 0.8346 - accuracy: 0.6046 - f1-score: 0.6651 - val_loss: 7.0386 - val_iou_score: 0.8746 - val_accuracy: 0.2771 - val_f1-score: 0.6907
# Epoch 16/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6481 - iou_score: 0.3739 - accuracy: 0.5783 - f1-score: 0.4660
# Epoch 00016: loss did not improve from 2.02611
# 2/2 [==============================] - 14s 7s/step - loss: 2.3286 - iou_score: 0.4304 - accuracy: 0.5991 - f1-score: 0.4876 - val_loss: 7.0119 - val_iou_score: 0.8553 - val_accuracy: 0.2787 - val_f1-score: 0.6691
# Epoch 17/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.0655 - iou_score: 0.3509 - accuracy: 0.6043 - f1-score: 0.4598
# Epoch 00017: loss improved from 2.02611 to 1.89907, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 1.8991 - iou_score: 0.8955 - accuracy: 0.6038 - f1-score: 0.6796 - val_loss: 6.9659 - val_iou_score: 13.5683 - val_accuracy: 0.2803 - val_f1-score: 0.6364
# Epoch 18/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1599 - iou_score: 1.0204 - accuracy: 0.6022 - f1-score: 0.6672
# Epoch 00018: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 1.9787 - iou_score: 1.0225 - accuracy: 0.6031 - f1-score: 0.7255 - val_loss: 6.8156 - val_iou_score: 0.8572 - val_accuracy: 0.2859 - val_f1-score: 0.4343
# Epoch 19/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1925 - iou_score: 0.3365 - accuracy: 0.6135 - f1-score: 0.4471
# Epoch 00019: loss did not improve from 1.89907
# 2/2 [==============================] - 17s 8s/step - loss: 2.1955 - iou_score: 0.3283 - accuracy: 0.6127 - f1-score: 0.4389 - val_loss: 6.6476 - val_iou_score: 0.1990 - val_accuracy: 0.2933 - val_f1-score: 0.2372
# Epoch 20/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6581 - iou_score: 0.3353 - accuracy: 0.5799 - f1-score: 0.4380
# Epoch 00020: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.5752 - iou_score: 0.3171 - accuracy: 0.5812 - f1-score: 0.4224 - val_loss: 6.4509 - val_iou_score: 0.3504 - val_accuracy: 0.3020 - val_f1-score: -0.1961
# Epoch 21/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.4138 - iou_score: -64.8372 - accuracy: 0.5919 - f1-score: 0.8090
# Epoch 00021: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.1865 - iou_score: -32.2506 - accuracy: 0.6078 - f1-score: 0.6218 - val_loss: 6.2410 - val_iou_score: -2.9732 - val_accuracy: 0.3124 - val_f1-score: 0.4980
# Epoch 22/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.7591 - iou_score: -56.9820 - accuracy: 0.5654 - f1-score: 0.7423
# Epoch 00022: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.7562 - iou_score: -28.3380 - accuracy: 0.5718 - f1-score: 0.5711 - val_loss: 6.1934 - val_iou_score: 0.2995 - val_accuracy: 0.3114 - val_f1-score: 0.7127
# Epoch 23/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.4924 - iou_score: 0.2287 - accuracy: 0.5885 - f1-score: 0.3365
# Epoch 00023: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.5938 - iou_score: 0.2347 - accuracy: 0.5849 - f1-score: 0.3334 - val_loss: 6.1621 - val_iou_score: 0.3002 - val_accuracy: 0.3102 - val_f1-score: 0.5841
# Epoch 24/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6179 - iou_score: 0.2376 - accuracy: 0.5724 - f1-score: 0.3502
# Epoch 00024: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.3049 - iou_score: 0.6275 - accuracy: 0.5903 - f1-score: 0.4875 - val_loss: 6.0865 - val_iou_score: 0.3928 - val_accuracy: 0.3111 - val_f1-score: 0.4979
# Epoch 25/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.5110 - iou_score: 0.1491 - accuracy: 0.5860 - f1-score: 0.2360
# Epoch 00025: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.2746 - iou_score: 0.2062 - accuracy: 0.6029 - f1-score: 0.3066 - val_loss: 6.0337 - val_iou_score: 0.5398 - val_accuracy: 0.3130 - val_f1-score: 0.5320
# Epoch 26/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6652 - iou_score: 0.1456 - accuracy: 0.5791 - f1-score: 0.2356
# Epoch 00026: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.6493 - iou_score: 0.1273 - accuracy: 0.5810 - f1-score: 0.2024 - val_loss: 5.9323 - val_iou_score: 0.2696 - val_accuracy: 0.3177 - val_f1-score: 0.5254
# Epoch 27/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9793 - iou_score: 0.2759 - accuracy: 0.6271 - f1-score: 0.3855
# Epoch 00027: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.1998 - iou_score: 0.2839 - accuracy: 0.6061 - f1-score: 0.3910 - val_loss: 5.7718 - val_iou_score: 0.9942 - val_accuracy: 0.3254 - val_f1-score: 0.5158
# Epoch 28/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7764 - iou_score: 0.3535 - accuracy: 0.6313 - f1-score: 0.4362
# Epoch 00028: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.0575 - iou_score: 0.2742 - accuracy: 0.6123 - f1-score: 0.3684 - val_loss: 5.6048 - val_iou_score: -0.2607 - val_accuracy: 0.3348 - val_f1-score: 0.5092
# Epoch 29/500
# 1/2 [==============>...............] - ETA: 0s - loss: 3.4919 - iou_score: -0.0869 - accuracy: 0.5221 - f1-score: -0.1999
# Epoch 00029: loss did not improve from 1.89907
# 2/2 [==============================] - 14s 7s/step - loss: 2.6334 - iou_score: -1.1121 - accuracy: 0.5665 - f1-score: 0.3462 - val_loss: 5.3583 - val_iou_score: 0.3399 - val_accuracy: 0.3459 - val_f1-score: 0.4986
# Epoch 30/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6986 - iou_score: 0.9053 - accuracy: 0.6073 - f1-score: 0.7616
# Epoch 00030: loss improved from 1.89907 to 1.71927, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 1.7193 - iou_score: 0.6245 - accuracy: 0.6209 - f1-score: 0.6043 - val_loss: 5.0858 - val_iou_score: 48.2308 - val_accuracy: 0.3606 - val_f1-score: 0.4874
# Epoch 31/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8849 - iou_score: 0.2921 - accuracy: 0.6177 - f1-score: 0.4026
# Epoch 00031: loss did not improve from 1.71927
# 2/2 [==============================] - 14s 7s/step - loss: 1.8351 - iou_score: 0.3071 - accuracy: 0.6267 - f1-score: 0.4167 - val_loss: 4.8804 - val_iou_score: -3.5972 - val_accuracy: 0.3671 - val_f1-score: 0.4710
# Epoch 32/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2450 - iou_score: 0.2652 - accuracy: 0.5963 - f1-score: 0.3736
# Epoch 00032: loss did not improve from 1.71927
# 2/2 [==============================] - 14s 7s/step - loss: 1.9568 - iou_score: 0.3002 - accuracy: 0.6105 - f1-score: 0.4090 - val_loss: 4.6723 - val_iou_score: 1.4669 - val_accuracy: 0.3741 - val_f1-score: 0.0575
# Epoch 33/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.5606 - iou_score: 0.3436 - accuracy: 0.5885 - f1-score: 0.4147
# Epoch 00033: loss did not improve from 1.71927
# 2/2 [==============================] - 14s 7s/step - loss: 2.4074 - iou_score: 0.2679 - accuracy: 0.5930 - f1-score: 0.3565 - val_loss: 4.4310 - val_iou_score: -1.3365 - val_accuracy: 0.3844 - val_f1-score: 0.7498
# Epoch 34/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8847 - iou_score: 0.2370 - accuracy: 0.6296 - f1-score: 0.3482
# Epoch 00034: loss did not improve from 1.71927
# 2/2 [==============================] - 14s 7s/step - loss: 1.9451 - iou_score: 0.7256 - accuracy: 0.6119 - f1-score: 0.5152 - val_loss: 4.2187 - val_iou_score: 4.4352 - val_accuracy: 0.3957 - val_f1-score: 0.5611
# Epoch 35/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6429 - iou_score: 0.3411 - accuracy: 0.6324 - f1-score: 0.4395
# Epoch 00035: loss did not improve from 1.71927
# 2/2 [==============================] - 14s 7s/step - loss: 1.8125 - iou_score: 0.2878 - accuracy: 0.6296 - f1-score: 0.3932 - val_loss: 4.0707 - val_iou_score: -2.2908 - val_accuracy: 0.4065 - val_f1-score: 0.5405
# Epoch 36/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5238 - iou_score: 0.8149 - accuracy: 0.6143 - f1-score: 0.7302
# Epoch 00036: loss improved from 1.71927 to 1.70596, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 1.7060 - iou_score: 0.5374 - accuracy: 0.6217 - f1-score: 0.5515 - val_loss: 3.9494 - val_iou_score: -2.4604 - val_accuracy: 0.4153 - val_f1-score: 0.5230
# Epoch 37/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5844 - iou_score: 0.3447 - accuracy: 0.6245 - f1-score: 0.4494
# Epoch 00037: loss did not improve from 1.70596
# 2/2 [==============================] - 14s 7s/step - loss: 1.8921 - iou_score: 0.2705 - accuracy: 0.6133 - f1-score: 0.3750 - val_loss: 3.8520 - val_iou_score: -1.1491 - val_accuracy: 0.4246 - val_f1-score: 0.5283
# Epoch 38/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1756 - iou_score: 0.8721 - accuracy: 0.6384 - f1-score: 0.7081
# Epoch 00038: loss improved from 1.70596 to 1.52665, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 1.5267 - iou_score: 0.5737 - accuracy: 0.6308 - f1-score: 0.5484 - val_loss: 3.7490 - val_iou_score: 0.8223 - val_accuracy: 0.4345 - val_f1-score: 0.5270
# Epoch 39/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6460 - iou_score: 6.6336 - accuracy: 0.6164 - f1-score: 0.8166
# Epoch 00039: loss did not improve from 1.52665
# 2/2 [==============================] - 14s 7s/step - loss: 1.8200 - iou_score: 3.5248 - accuracy: 0.6118 - f1-score: 0.6504 - val_loss: 3.6188 - val_iou_score: 1.1309 - val_accuracy: 0.4494 - val_f1-score: 0.5643
# Epoch 40/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5898 - iou_score: 0.2738 - accuracy: 0.6256 - f1-score: 0.3877
# Epoch 00040: loss did not improve from 1.52665
# 2/2 [==============================] - 14s 7s/step - loss: 1.5749 - iou_score: 0.2796 - accuracy: 0.6307 - f1-score: 0.3937 - val_loss: 3.5202 - val_iou_score: 0.6635 - val_accuracy: 0.4651 - val_f1-score: 0.5575
# Epoch 41/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5825 - iou_score: 3.5154 - accuracy: 0.6200 - f1-score: 0.7914
# Epoch 00041: loss improved from 1.52665 to 1.50461, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 1.5046 - iou_score: 1.9949 - accuracy: 0.6273 - f1-score: 0.6712 - val_loss: 3.4139 - val_iou_score: 5.6679 - val_accuracy: 0.4797 - val_f1-score: 0.5096
# Epoch 42/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5479 - iou_score: -2.1820 - accuracy: 0.6296 - f1-score: 0.8852
# Epoch 00042: loss did not improve from 1.50461
# 2/2 [==============================] - 14s 7s/step - loss: 1.7580 - iou_score: -0.9797 - accuracy: 0.6207 - f1-score: 0.6095 - val_loss: 3.3542 - val_iou_score: 4.0759 - val_accuracy: 0.4872 - val_f1-score: 1.2116
# Epoch 43/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8615 - iou_score: 0.3580 - accuracy: 0.6149 - f1-score: 0.4361
# Epoch 00043: loss did not improve from 1.50461
# 2/2 [==============================] - 14s 7s/step - loss: 1.8235 - iou_score: 0.5420 - accuracy: 0.6219 - f1-score: 0.4987 - val_loss: 3.3003 - val_iou_score: -0.0410 - val_accuracy: 0.4948 - val_f1-score: 0.5765
# Epoch 44/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7006 - iou_score: 0.3965 - accuracy: 0.6211 - f1-score: 0.4832
# Epoch 00044: loss did not improve from 1.50461
# 2/2 [==============================] - 14s 7s/step - loss: 1.7623 - iou_score: 0.3291 - accuracy: 0.6210 - f1-score: 0.4249 - val_loss: 3.2197 - val_iou_score: 0.8397 - val_accuracy: 0.5025 - val_f1-score: 0.3189
# Epoch 45/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0643 - iou_score: 0.8562 - accuracy: 0.6412 - f1-score: 0.7394
# Epoch 00045: loss improved from 1.50461 to 1.31637, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 1.3164 - iou_score: 0.6950 - accuracy: 0.6340 - f1-score: 0.6609 - val_loss: 3.1334 - val_iou_score: 2.1497 - val_accuracy: 0.5098 - val_f1-score: 0.5425
# Epoch 46/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7146 - iou_score: 0.2831 - accuracy: 0.6446 - f1-score: 0.3974
# Epoch 00046: loss did not improve from 1.31637
# 2/2 [==============================] - 15s 7s/step - loss: 1.6840 - iou_score: 0.3147 - accuracy: 0.6341 - f1-score: 0.4216 - val_loss: 3.0837 - val_iou_score: 0.3118 - val_accuracy: 0.5144 - val_f1-score: 0.4938
# Epoch 47/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3350 - iou_score: 1.5582 - accuracy: 0.6327 - f1-score: 0.7752
# Epoch 00047: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5430 - iou_score: 0.9890 - accuracy: 0.6269 - f1-score: 0.6357 - val_loss: 3.0076 - val_iou_score: 0.4460 - val_accuracy: 0.5203 - val_f1-score: 0.6084
# Epoch 48/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7329 - iou_score: 0.2553 - accuracy: 0.6476 - f1-score: 0.3668
# Epoch 00048: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.7011 - iou_score: 0.3459 - accuracy: 0.6350 - f1-score: 0.4358 - val_loss: 2.9255 - val_iou_score: 0.2117 - val_accuracy: 0.5263 - val_f1-score: 0.4718
# Epoch 49/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5648 - iou_score: 0.2903 - accuracy: 0.6368 - f1-score: 0.4004
# Epoch 00049: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.4960 - iou_score: 0.3171 - accuracy: 0.6396 - f1-score: 0.4270 - val_loss: 2.8726 - val_iou_score: -1.3452 - val_accuracy: 0.5311 - val_f1-score: 0.7115
# Epoch 50/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7863 - iou_score: 0.3067 - accuracy: 0.6277 - f1-score: 0.3954
# Epoch 00050: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.6725 - iou_score: 0.2977 - accuracy: 0.6332 - f1-score: 0.3981 - val_loss: 2.8204 - val_iou_score: -0.1549 - val_accuracy: 0.5370 - val_f1-score: 0.6798
# Epoch 51/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4642 - iou_score: 0.5635 - accuracy: 0.6295 - f1-score: 0.5722
# Epoch 00051: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5133 - iou_score: 0.4099 - accuracy: 0.6371 - f1-score: 0.4695 - val_loss: 2.7592 - val_iou_score: -0.0288 - val_accuracy: 0.5431 - val_f1-score: 0.7552
# Epoch 52/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5546 - iou_score: 0.6151 - accuracy: 0.6271 - f1-score: 0.5797
# Epoch 00052: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5016 - iou_score: 0.5178 - accuracy: 0.6294 - f1-score: 0.5376 - val_loss: 2.7362 - val_iou_score: -0.0576 - val_accuracy: 0.5455 - val_f1-score: 0.4965
# Epoch 53/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5157 - iou_score: 0.6940 - accuracy: 0.6304 - f1-score: 0.5999
# Epoch 00053: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5856 - iou_score: 0.6051 - accuracy: 0.6284 - f1-score: 0.5496 - val_loss: 2.7032 - val_iou_score: 0.2940 - val_accuracy: 0.5398 - val_f1-score: 0.2256
# Epoch 54/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2101 - iou_score: 0.3263 - accuracy: 0.6118 - f1-score: 0.4053
# Epoch 00054: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.8707 - iou_score: 0.3470 - accuracy: 0.6213 - f1-score: 0.4336 - val_loss: 2.6692 - val_iou_score: 2.5226 - val_accuracy: 0.5346 - val_f1-score: 0.7050
# Epoch 55/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4433 - iou_score: 20.3501 - accuracy: 0.6316 - f1-score: 0.8327
# Epoch 00055: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.4528 - iou_score: 10.3084 - accuracy: 0.6367 - f1-score: 0.6065 - val_loss: 2.6677 - val_iou_score: -20.7234 - val_accuracy: 0.5305 - val_f1-score: 0.7797
# Epoch 56/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6897 - iou_score: 0.4347 - accuracy: 0.6270 - f1-score: 0.4703
# Epoch 00056: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.6297 - iou_score: 0.3810 - accuracy: 0.6286 - f1-score: 0.4496 - val_loss: 2.6732 - val_iou_score: 0.0566 - val_accuracy: 0.5265 - val_f1-score: 0.6387
# Epoch 57/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5327 - iou_score: 0.3460 - accuracy: 0.6334 - f1-score: 0.4474
# Epoch 00057: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.7558 - iou_score: 0.4904 - accuracy: 0.6267 - f1-score: 0.4705 - val_loss: 2.6290 - val_iou_score: -0.2487 - val_accuracy: 0.5278 - val_f1-score: 1.1032
# Epoch 58/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4552 - iou_score: 0.3076 - accuracy: 0.6441 - f1-score: 0.4208
# Epoch 00058: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5389 - iou_score: 0.2839 - accuracy: 0.6374 - f1-score: 0.3963 - val_loss: 2.5856 - val_iou_score: -2.6171 - val_accuracy: 0.5280 - val_f1-score: 1.1619
# Epoch 59/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5674 - iou_score: 0.3747 - accuracy: 0.6312 - f1-score: 0.4463
# Epoch 00059: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5210 - iou_score: 0.3440 - accuracy: 0.6344 - f1-score: 0.4325 - val_loss: 2.5576 - val_iou_score: 6.5851 - val_accuracy: 0.5269 - val_f1-score: 0.7904
# Epoch 60/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6236 - iou_score: 0.4287 - accuracy: 0.6325 - f1-score: 0.4619
# Epoch 00060: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5404 - iou_score: 0.4750 - accuracy: 0.6346 - f1-score: 0.4906 - val_loss: 2.6025 - val_iou_score: -0.2685 - val_accuracy: 0.5254 - val_f1-score: 1.0326
# Epoch 61/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5856 - iou_score: 0.2558 - accuracy: 0.6520 - f1-score: 0.3665
# Epoch 00061: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.6085 - iou_score: 0.2731 - accuracy: 0.6442 - f1-score: 0.3833 - val_loss: 2.6284 - val_iou_score: 0.2318 - val_accuracy: 0.5264 - val_f1-score: 1.5717
# Epoch 62/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6508 - iou_score: 0.2450 - accuracy: 0.6470 - f1-score: 0.3503
# Epoch 00062: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.3679 - iou_score: 0.8802 - accuracy: 0.6460 - f1-score: 0.5732 - val_loss: 2.6109 - val_iou_score: 2.3120 - val_accuracy: 0.5316 - val_f1-score: 0.8701
# Epoch 63/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3692 - iou_score: 0.3686 - accuracy: 0.6373 - f1-score: 0.4642
# Epoch 00063: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.3600 - iou_score: 0.3781 - accuracy: 0.6368 - f1-score: 0.4689 - val_loss: 2.5724 - val_iou_score: 5.9336 - val_accuracy: 0.5375 - val_f1-score: 0.8150
# Epoch 64/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6024 - iou_score: 1.3375 - accuracy: 0.6262 - f1-score: 0.6384
# Epoch 00064: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.3764 - iou_score: 1.0922 - accuracy: 0.6364 - f1-score: 0.6635 - val_loss: 2.5306 - val_iou_score: 0.9398 - val_accuracy: 0.5430 - val_f1-score: 0.7636
# Epoch 65/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5924 - iou_score: 0.2403 - accuracy: 0.6472 - f1-score: 0.3450
# Epoch 00065: loss did not improve from 1.31637
# 2/2 [==============================] - 14s 7s/step - loss: 1.5534 - iou_score: 0.2857 - accuracy: 0.6406 - f1-score: 0.3936 - val_loss: 2.4445 - val_iou_score: 1.9398 - val_accuracy: 0.5508 - val_f1-score: 0.8224
# Epoch 66/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1830 - iou_score: 0.4976 - accuracy: 0.6437 - f1-score: 0.5411
# Epoch 00066: loss improved from 1.31637 to 1.10181, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 1.1018 - iou_score: 0.4418 - accuracy: 0.6535 - f1-score: 0.5150 - val_loss: 2.3789 - val_iou_score: 4.4619 - val_accuracy: 0.5564 - val_f1-score: 0.8432
# Epoch 67/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2439 - iou_score: 0.3337 - accuracy: 0.6515 - f1-score: 0.4431
# Epoch 00067: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.2932 - iou_score: 0.5011 - accuracy: 0.6457 - f1-score: 0.5546 - val_loss: 2.3186 - val_iou_score: 0.6689 - val_accuracy: 0.5597 - val_f1-score: 0.7350
# Epoch 68/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1833 - iou_score: 0.3515 - accuracy: 0.6525 - f1-score: 0.4594
# Epoch 00068: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.2505 - iou_score: 0.5238 - accuracy: 0.6469 - f1-score: 0.5098 - val_loss: 2.3094 - val_iou_score: 0.3887 - val_accuracy: 0.5642 - val_f1-score: 0.7089
# Epoch 69/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3019 - iou_score: 0.2905 - accuracy: 0.6512 - f1-score: 0.3981
# Epoch 00069: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.9078 - iou_score: 0.1348 - accuracy: 0.6189 - f1-score: 0.1756 - val_loss: 2.2943 - val_iou_score: 0.3547 - val_accuracy: 0.5688 - val_f1-score: 0.6977
# Epoch 70/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2782 - iou_score: 0.2468 - accuracy: 0.6566 - f1-score: 0.3601
# Epoch 00070: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.3820 - iou_score: 0.2509 - accuracy: 0.6507 - f1-score: 0.3638 - val_loss: 2.2949 - val_iou_score: 0.1554 - val_accuracy: 0.5715 - val_f1-score: 0.7091
# Epoch 71/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7476 - iou_score: 0.8897 - accuracy: 0.6285 - f1-score: 0.5415
# Epoch 00071: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.6171 - iou_score: 0.5638 - accuracy: 0.6400 - f1-score: 0.4452 - val_loss: 2.2777 - val_iou_score: 0.4538 - val_accuracy: 0.5758 - val_f1-score: 0.1223
# Epoch 72/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2421 - iou_score: 0.3273 - accuracy: 0.6580 - f1-score: 0.4335
# Epoch 00072: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.2019 - iou_score: 0.4401 - accuracy: 0.6513 - f1-score: 0.4849 - val_loss: 2.2761 - val_iou_score: 0.5418 - val_accuracy: 0.5788 - val_f1-score: 0.4363
# Epoch 73/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2119 - iou_score: 0.3831 - accuracy: 0.6413 - f1-score: 0.4730
# Epoch 00073: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.1699 - iou_score: 0.4094 - accuracy: 0.6430 - f1-score: 0.4828 - val_loss: 2.2476 - val_iou_score: 0.6993 - val_accuracy: 0.5831 - val_f1-score: 0.6076
# Epoch 74/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3847 - iou_score: 0.2568 - accuracy: 0.6564 - f1-score: 0.3706
# Epoch 00074: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.3063 - iou_score: 0.3090 - accuracy: 0.6544 - f1-score: 0.4181 - val_loss: 2.2223 - val_iou_score: 0.7825 - val_accuracy: 0.5871 - val_f1-score: 0.6423
# Epoch 75/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8586 - iou_score: 0.3582 - accuracy: 0.6343 - f1-score: 0.4297
# Epoch 00075: loss did not improve from 1.10181
# 2/2 [==============================] - 14s 7s/step - loss: 1.6095 - iou_score: 0.3472 - accuracy: 0.6377 - f1-score: 0.4316 - val_loss: 2.1773 - val_iou_score: 0.7217 - val_accuracy: 0.5911 - val_f1-score: 0.2944
# Epoch 76/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0628 - iou_score: 0.4466 - accuracy: 0.6490 - f1-score: 0.5084
# Epoch 00076: loss improved from 1.10181 to 1.03748, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 1.0375 - iou_score: 0.4481 - accuracy: 0.6559 - f1-score: 0.5188 - val_loss: 2.1559 - val_iou_score: 0.0319 - val_accuracy: 0.5945 - val_f1-score: 0.7629
# Epoch 77/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0848 - iou_score: 0.4280 - accuracy: 0.6467 - f1-score: 0.5022
# Epoch 00077: loss did not improve from 1.03748
# 2/2 [==============================] - 14s 7s/step - loss: 1.1766 - iou_score: 0.3561 - accuracy: 0.6521 - f1-score: 0.4503 - val_loss: 2.1568 - val_iou_score: 0.6319 - val_accuracy: 0.5980 - val_f1-score: 0.4356
# Epoch 78/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0174 - iou_score: 0.4769 - accuracy: 0.6501 - f1-score: 0.5242
# Epoch 00078: loss improved from 1.03748 to 1.00155, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 1.0015 - iou_score: 0.4613 - accuracy: 0.6572 - f1-score: 0.5261 - val_loss: 2.1783 - val_iou_score: 0.6893 - val_accuracy: 0.6007 - val_f1-score: 0.4874
# Epoch 79/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0642 - iou_score: 0.3916 - accuracy: 0.6488 - f1-score: 0.4854
# Epoch 00079: loss did not improve from 1.00155
# 2/2 [==============================] - 14s 7s/step - loss: 1.1193 - iou_score: 0.4861 - accuracy: 0.6445 - f1-score: 0.5155 - val_loss: 2.1988 - val_iou_score: 0.7141 - val_accuracy: 0.6030 - val_f1-score: 0.4757
# Epoch 80/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1751 - iou_score: 0.5783 - accuracy: 0.6409 - f1-score: 0.5521
# Epoch 00080: loss did not improve from 1.00155
# 2/2 [==============================] - 14s 7s/step - loss: 1.0802 - iou_score: 0.5630 - accuracy: 0.6462 - f1-score: 0.5476 - val_loss: 2.2022 - val_iou_score: 0.6779 - val_accuracy: 0.6051 - val_f1-score: 0.5642
# Epoch 81/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0039 - iou_score: 0.5589 - accuracy: 0.6505 - f1-score: 0.5443
# Epoch 00081: loss did not improve from 1.00155
# 2/2 [==============================] - 14s 7s/step - loss: 1.3790 - iou_score: 0.7984 - accuracy: 0.6475 - f1-score: 0.5586 - val_loss: 2.1808 - val_iou_score: 0.5258 - val_accuracy: 0.6080 - val_f1-score: 0.6074
# Epoch 82/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9450 - iou_score: 0.4673 - accuracy: 0.6528 - f1-score: 0.5238
# Epoch 00082: loss improved from 1.00155 to 0.96893, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 0.9689 - iou_score: 0.4698 - accuracy: 0.6503 - f1-score: 0.5268 - val_loss: 2.1435 - val_iou_score: 0.7064 - val_accuracy: 0.6105 - val_f1-score: 0.4721
# Epoch 83/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7574 - iou_score: 0.7227 - accuracy: 0.6559 - f1-score: 0.6630
# Epoch 00083: loss improved from 0.96893 to 0.87598, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 0.8760 - iou_score: 0.6449 - accuracy: 0.6510 - f1-score: 0.6111 - val_loss: 2.0918 - val_iou_score: 0.2577 - val_accuracy: 0.6145 - val_f1-score: 0.6478
# Epoch 84/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0711 - iou_score: 0.3342 - accuracy: 0.6557 - f1-score: 0.4416
# Epoch 00084: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.0362 - iou_score: 0.6486 - accuracy: 0.6526 - f1-score: 0.5353 - val_loss: 2.0626 - val_iou_score: 0.7611 - val_accuracy: 0.6175 - val_f1-score: -0.1233
# Epoch 85/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0658 - iou_score: 0.3786 - accuracy: 0.6603 - f1-score: 0.4803
# Epoch 00085: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 0.9812 - iou_score: 0.5001 - accuracy: 0.6569 - f1-score: 0.5269 - val_loss: 2.0442 - val_iou_score: 1.6346 - val_accuracy: 0.6199 - val_f1-score: 0.5836
# Epoch 86/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1100 - iou_score: 0.3443 - accuracy: 0.6544 - f1-score: 0.4530
# Epoch 00086: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.0048 - iou_score: 0.4842 - accuracy: 0.6532 - f1-score: 0.5132 - val_loss: 2.0277 - val_iou_score: 1.4178 - val_accuracy: 0.6221 - val_f1-score: 0.1959
# Epoch 87/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0969 - iou_score: 2.2958 - accuracy: 0.6461 - f1-score: 0.7239
# Epoch 00087: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.2221 - iou_score: 1.2656 - accuracy: 0.6485 - f1-score: 0.5352 - val_loss: 1.9809 - val_iou_score: 3.8526 - val_accuracy: 0.6254 - val_f1-score: 0.3065
# Epoch 88/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8758 - iou_score: 0.5543 - accuracy: 0.6537 - f1-score: 0.5513
# Epoch 00088: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.1164 - iou_score: 0.4036 - accuracy: 0.6561 - f1-score: 0.4557 - val_loss: 1.9271 - val_iou_score: -0.4479 - val_accuracy: 0.6283 - val_f1-score: 0.3585
# Epoch 89/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0091 - iou_score: 0.3665 - accuracy: 0.6595 - f1-score: 0.4727
# Epoch 00089: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 0.9643 - iou_score: 0.3859 - accuracy: 0.6536 - f1-score: 0.4828 - val_loss: 1.8769 - val_iou_score: -0.8307 - val_accuracy: 0.6316 - val_f1-score: 3.7690
# Epoch 90/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2995 - iou_score: 0.2329 - accuracy: 0.6598 - f1-score: 0.3372
# Epoch 00090: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.1535 - iou_score: 0.3333 - accuracy: 0.6566 - f1-score: 0.4302 - val_loss: 1.8350 - val_iou_score: 1.3970 - val_accuracy: 0.6351 - val_f1-score: 0.4283
# Epoch 91/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9127 - iou_score: 0.6584 - accuracy: 0.6516 - f1-score: 0.5719
# Epoch 00091: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.0055 - iou_score: 0.4723 - accuracy: 0.6546 - f1-score: 0.4857 - val_loss: 1.7990 - val_iou_score: -0.1126 - val_accuracy: 0.6366 - val_f1-score: -0.5867
# Epoch 92/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3087 - iou_score: 0.2226 - accuracy: 0.6595 - f1-score: 0.3329
# Epoch 00092: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.0606 - iou_score: 0.3456 - accuracy: 0.6576 - f1-score: 0.4269 - val_loss: 1.7598 - val_iou_score: 117.1789 - val_accuracy: 0.6378 - val_f1-score: 0.5888
# Epoch 93/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3134 - iou_score: 0.2380 - accuracy: 0.6585 - f1-score: 0.3468
# Epoch 00093: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.2827 - iou_score: 0.2239 - accuracy: 0.6610 - f1-score: 0.3295 - val_loss: 1.7437 - val_iou_score: 0.8373 - val_accuracy: 0.6381 - val_f1-score: 0.2263
# Epoch 94/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2760 - iou_score: 0.2203 - accuracy: 0.6619 - f1-score: 0.3294
# Epoch 00094: loss did not improve from 0.87598
# 2/2 [==============================] - 14s 7s/step - loss: 1.0487 - iou_score: 0.3367 - accuracy: 0.6589 - f1-score: 0.4220 - val_loss: 1.7394 - val_iou_score: 0.4755 - val_accuracy: 0.6378 - val_f1-score: 0.5586
# Epoch 95/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6119 - iou_score: 0.6072 - accuracy: 0.6571 - f1-score: 0.6283
# Epoch 00095: loss improved from 0.87598 to 0.71524, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 8s/step - loss: 0.7152 - iou_score: 0.5424 - accuracy: 0.6565 - f1-score: 0.5740 - val_loss: 1.7173 - val_iou_score: -0.7600 - val_accuracy: 0.6398 - val_f1-score: 0.6742
# Epoch 96/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9136 - iou_score: 0.4154 - accuracy: 0.6508 - f1-score: 0.4863
# Epoch 00096: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 0.8592 - iou_score: 0.4678 - accuracy: 0.6535 - f1-score: 0.5103 - val_loss: 1.7131 - val_iou_score: 10.8941 - val_accuracy: 0.6406 - val_f1-score: -7.4043
# Epoch 97/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2405 - iou_score: 0.2361 - accuracy: 0.6623 - f1-score: 0.3456
# Epoch 00097: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 1.3550 - iou_score: 0.2033 - accuracy: 0.6472 - f1-score: 0.3081 - val_loss: 1.6962 - val_iou_score: -0.6080 - val_accuracy: 0.6415 - val_f1-score: 0.9091
# Epoch 98/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6487 - iou_score: 0.6953 - accuracy: 0.6587 - f1-score: 0.6324
# Epoch 00098: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 1.2531 - iou_score: 0.3392 - accuracy: 0.6310 - f1-score: 0.2984 - val_loss: 1.6619 - val_iou_score: -1.9724 - val_accuracy: 0.6427 - val_f1-score: 2.1624
# Epoch 99/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9366 - iou_score: 0.3442 - accuracy: 0.6530 - f1-score: 0.4482
# Epoch 00099: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 0.8696 - iou_score: 0.4113 - accuracy: 0.6563 - f1-score: 0.5024 - val_loss: 1.6327 - val_iou_score: 0.0485 - val_accuracy: 0.6437 - val_f1-score: 0.6066
# Epoch 100/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1836 - iou_score: 0.2143 - accuracy: 0.6668 - f1-score: 0.3121
# Epoch 00100: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 1.0268 - iou_score: 0.3884 - accuracy: 0.6554 - f1-score: 0.4256 - val_loss: 1.6110 - val_iou_score: -0.4273 - val_accuracy: 0.6440 - val_f1-score: 1.8336
# Epoch 101/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8731 - iou_score: 0.3642 - accuracy: 0.6549 - f1-score: 0.4586
# Epoch 00101: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 0.9779 - iou_score: 0.3162 - accuracy: 0.6561 - f1-score: 0.4197 - val_loss: 1.5952 - val_iou_score: -0.5262 - val_accuracy: 0.6442 - val_f1-score: 0.9951
# Epoch 102/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0124 - iou_score: 0.2658 - accuracy: 0.6656 - f1-score: 0.3795
# Epoch 00102: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 0.9601 - iou_score: 0.2692 - accuracy: 0.6587 - f1-score: 0.3830 - val_loss: 1.5822 - val_iou_score: 0.0538 - val_accuracy: 0.6445 - val_f1-score: 0.4481
# Epoch 103/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0938 - iou_score: 0.2556 - accuracy: 0.6582 - f1-score: 0.3674
# Epoch 00103: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 0.9755 - iou_score: 0.2997 - accuracy: 0.6571 - f1-score: 0.4055 - val_loss: 1.5730 - val_iou_score: 0.1911 - val_accuracy: 0.6450 - val_f1-score: 0.6047
# Epoch 104/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8735 - iou_score: 0.3497 - accuracy: 0.6552 - f1-score: 0.4427
# Epoch 00104: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 0.9971 - iou_score: 0.2952 - accuracy: 0.6552 - f1-score: 0.3962 - val_loss: 1.5614 - val_iou_score: 1.0339 - val_accuracy: 0.6454 - val_f1-score: 0.7374
# Epoch 105/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1428 - iou_score: 0.4544 - accuracy: 0.6502 - f1-score: 0.4875
# Epoch 00105: loss did not improve from 0.71524
# 2/2 [==============================] - 14s 7s/step - loss: 1.1420 - iou_score: 0.3341 - accuracy: 0.6589 - f1-score: 0.4038 - val_loss: 1.5409 - val_iou_score: -0.3963 - val_accuracy: 0.6468 - val_f1-score: 1.0944
# Epoch 106/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8027 - iou_score: 0.2866 - accuracy: 0.6546 - f1-score: 0.4007
# Epoch 00106: loss improved from 0.71524 to 0.68541, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 0.6854 - iou_score: 0.4297 - accuracy: 0.6578 - f1-score: 0.5081 - val_loss: 1.5212 - val_iou_score: 0.0455 - val_accuracy: 0.6485 - val_f1-score: 0.8293
# Epoch 107/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1417 - iou_score: 0.2161 - accuracy: 0.6671 - f1-score: 0.3136
# Epoch 00107: loss did not improve from 0.68541
# 2/2 [==============================] - 14s 7s/step - loss: 1.1456 - iou_score: 0.2181 - accuracy: 0.6651 - f1-score: 0.3210 - val_loss: 1.5145 - val_iou_score: -1.0175 - val_accuracy: 0.6489 - val_f1-score: 0.8230
# Epoch 108/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1134 - iou_score: 0.4609 - accuracy: 0.6507 - f1-score: 0.4706
# Epoch 00108: loss did not improve from 0.68541
# 2/2 [==============================] - 14s 7s/step - loss: 0.9332 - iou_score: 0.3885 - accuracy: 0.6543 - f1-score: 0.4482 - val_loss: 1.5012 - val_iou_score: 1.9472 - val_accuracy: 0.6493 - val_f1-score: 0.6902
# Epoch 109/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8289 - iou_score: 0.3682 - accuracy: 0.6581 - f1-score: 0.4496
# Epoch 00109: loss did not improve from 0.68541
# 2/2 [==============================] - 14s 7s/step - loss: 0.8720 - iou_score: 0.8005 - accuracy: 0.6542 - f1-score: 0.5387 - val_loss: 1.4967 - val_iou_score: -0.1660 - val_accuracy: 0.6490 - val_f1-score: 0.7033
# Epoch 110/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7967 - iou_score: 0.3334 - accuracy: 0.6554 - f1-score: 0.4438
# Epoch 00110: loss did not improve from 0.68541
# 2/2 [==============================] - 14s 7s/step - loss: 0.7648 - iou_score: 0.3609 - accuracy: 0.6566 - f1-score: 0.4673 - val_loss: 1.4900 - val_iou_score: 0.6338 - val_accuracy: 0.6490 - val_f1-score: 0.7515
# Epoch 111/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2180 - iou_score: 0.2290 - accuracy: 0.6631 - f1-score: 0.3226
# Epoch 00111: loss did not improve from 0.68541
# 2/2 [==============================] - 14s 7s/step - loss: 1.2122 - iou_score: 0.2329 - accuracy: 0.6633 - f1-score: 0.3259 - val_loss: 1.4870 - val_iou_score: 0.5799 - val_accuracy: 0.6492 - val_f1-score: 0.7381
# Epoch 112/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2272 - iou_score: 0.1783 - accuracy: 0.6517 - f1-score: 0.2813
# Epoch 00112: loss did not improve from 0.68541
# 2/2 [==============================] - 14s 7s/step - loss: 1.0330 - iou_score: 0.3188 - accuracy: 0.6526 - f1-score: 0.4125 - val_loss: 1.4748 - val_iou_score: 2.0232 - val_accuracy: 0.6502 - val_f1-score: 0.8238
# Epoch 113/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8061 - iou_score: 0.3440 - accuracy: 0.6564 - f1-score: 0.4499
# Epoch 00113: loss improved from 0.68541 to 0.64998, saving model to C:/Users/k v/Documents/REU/ShorelineDetection/model7/model_TL_UNET.h5
# 2/2 [==============================] - 15s 7s/step - loss: 0.6500 - iou_score: 1.0237 - accuracy: 0.6595 - f1-score: 0.5843 - val_loss: 1.4620 - val_iou_score: 0.5573 - val_accuracy: 0.6509 - val_f1-score: 2.7722
# Epoch 114/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9222 - iou_score: 0.2606 - accuracy: 0.6694 - f1-score: 0.3738
# Epoch 00114: loss did not improve from 0.64998
# 2/2 [==============================] - 14s 7s/step - loss: 0.9991 - iou_score: 0.2429 - accuracy: 0.6688 - f1-score: 0.3504 - val_loss: 1.4540 - val_iou_score: 0.3643 - val_accuracy: 0.6513 - val_f1-score: 1.2441
# Epoch 115/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8837 - iou_score: 0.2826 - accuracy: 0.6659 - f1-score: 0.3867
# Epoch 00115: loss did not improve from 0.64998
# 2/2 [==============================] - 14s 7s/step - loss: 0.7414 - iou_score: 0.4235 - accuracy: 0.6625 - f1-score: 0.4660 - val_loss: 1.4277 - val_iou_score: 0.4891 - val_accuracy: 0.6513 - val_f1-score: 1.5141
# Epoch 116/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8659 - iou_score: 0.3108 - accuracy: 0.6597 - f1-score: 0.4202
# Epoch 00116: loss did not improve from 0.64998
# 2/2 [==============================] - 14s 7s/step - loss: 0.9717 - iou_score: 0.2677 - accuracy: 0.6642 - f1-score: 0.3747 - val_loss: 1.4150 - val_iou_score: -12.8968 - val_accuracy: 0.6507 - val_f1-score: 0.8068
# Epoch 117/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7196 - iou_score: 0.3123 - accuracy: 0.6590 - f1-score: 0.4229
# Epoch 00117: loss did not improve from 0.64998
# ...
# 2/2 [==============================] - 15s 7s/step - loss: 0.4061 - iou_score: 0.3984 - accuracy: 0.6655 - f1-score: 0.4961 - val_loss: 0.5960 - val_iou_score: 0.2453 - val_accuracy: 0.6563 - val_f1-score: 0.1678
# Epoch 461/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4319 - iou_score: 0.3015 - accuracy: 0.6635 - f1-score: 0.4146
# Epoch 00461: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.4856 - iou_score: 0.3169 - accuracy: 0.6550 - f1-score: 0.4243 - val_loss: 0.5947 - val_iou_score: 0.2165 - val_accuracy: 0.6562 - val_f1-score: -0.0118
# Epoch 462/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3533 - iou_score: 0.4411 - accuracy: 0.6637 - f1-score: 0.5306
# Epoch 00462: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.3551 - iou_score: 0.4412 - accuracy: 0.6635 - f1-score: 0.5308 - val_loss: 0.5979 - val_iou_score: 0.2225 - val_accuracy: 0.6562 - val_f1-score: 1.1793
# Epoch 463/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3592 - iou_score: 0.4491 - accuracy: 0.6630 - f1-score: 0.5357
# Epoch 00463: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.3553 - iou_score: 0.4528 - accuracy: 0.6627 - f1-score: 0.5344 - val_loss: 0.6009 - val_iou_score: 0.2656 - val_accuracy: 0.6563 - val_f1-score: 0.6794
# Epoch 464/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3683 - iou_score: 0.4066 - accuracy: 0.6614 - f1-score: 0.5051
# Epoch 00464: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.3959 - iou_score: 0.3448 - accuracy: 0.6684 - f1-score: 0.4507 - val_loss: 0.6010 - val_iou_score: 0.2669 - val_accuracy: 0.6563 - val_f1-score: 0.1127
# Epoch 465/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4050 - iou_score: 0.3757 - accuracy: 0.6621 - f1-score: 0.4774
# Epoch 00465: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.4104 - iou_score: 0.3284 - accuracy: 0.6690 - f1-score: 0.4357 - val_loss: 0.6005 - val_iou_score: 0.2722 - val_accuracy: 0.6563 - val_f1-score: 0.2939
# Epoch 466/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4663 - iou_score: 0.3035 - accuracy: 0.6624 - f1-score: 0.4138
# Epoch 00466: loss did not improve from 0.33388
# 2/2 [==============================] - 16s 8s/step - loss: 0.5525 - iou_score: 0.3070 - accuracy: 0.6482 - f1-score: 0.4032 - val_loss: 0.5950 - val_iou_score: 0.2520 - val_accuracy: 0.6564 - val_f1-score: 0.2103
# Epoch 467/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4045 - iou_score: 0.3728 - accuracy: 0.6542 - f1-score: 0.4781
# Epoch 00467: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.4249 - iou_score: 0.3653 - accuracy: 0.6548 - f1-score: 0.4717 - val_loss: 0.5846 - val_iou_score: 0.2678 - val_accuracy: 0.6562 - val_f1-score: 0.6064
# Epoch 468/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5231 - iou_score: 0.3276 - accuracy: 0.6583 - f1-score: 0.4373
# Epoch 00468: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.4763 - iou_score: 0.3555 - accuracy: 0.6587 - f1-score: 0.4607 - val_loss: 0.5766 - val_iou_score: 0.3069 - val_accuracy: 0.6560 - val_f1-score: -0.4485
# Epoch 469/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3578 - iou_score: 0.4509 - accuracy: 0.6630 - f1-score: 0.5366
# Epoch 00469: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.3837 - iou_score: 0.3731 - accuracy: 0.6696 - f1-score: 0.4726 - val_loss: 0.5685 - val_iou_score: -0.1216 - val_accuracy: 0.6561 - val_f1-score: 0.5020
# Epoch 470/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4739 - iou_score: 0.2698 - accuracy: 0.6788 - f1-score: 0.3832
# Epoch 00470: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.5777 - iou_score: 0.2336 - accuracy: 0.6698 - f1-score: 0.3412 - val_loss: 0.5639 - val_iou_score: 0.1512 - val_accuracy: 0.6561 - val_f1-score: 0.4421
# Epoch 471/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6870 - iou_score: 0.2261 - accuracy: 0.6596 - f1-score: 0.3252
# Epoch 00471: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.5482 - iou_score: 0.2552 - accuracy: 0.6664 - f1-score: 0.3605 - val_loss: 0.5644 - val_iou_score: 0.2612 - val_accuracy: 0.6561 - val_f1-score: 0.2936
# Epoch 472/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4073 - iou_score: 0.3119 - accuracy: 0.6766 - f1-score: 0.4195
# Epoch 00472: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.5032 - iou_score: 0.2960 - accuracy: 0.6573 - f1-score: 0.4027 - val_loss: 0.5625 - val_iou_score: 0.3436 - val_accuracy: 0.6543 - val_f1-score: 0.3346
# Epoch 473/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3656 - iou_score: 0.4555 - accuracy: 0.6615 - f1-score: 0.5367
# Epoch 00473: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.3633 - iou_score: 0.4599 - accuracy: 0.6619 - f1-score: 0.5392 - val_loss: 0.5629 - val_iou_score: 0.2141 - val_accuracy: 0.6523 - val_f1-score: 0.3469
# Epoch 474/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3580 - iou_score: 0.4544 - accuracy: 0.6625 - f1-score: 0.5365
# Epoch 00474: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.3534 - iou_score: 0.4535 - accuracy: 0.6627 - f1-score: 0.5377 - val_loss: 0.5653 - val_iou_score: 0.2345 - val_accuracy: 0.6504 - val_f1-score: 0.3538
# Epoch 475/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4514 - iou_score: 0.2924 - accuracy: 0.6676 - f1-score: 0.3995
# Epoch 00475: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4138 - iou_score: 0.3973 - accuracy: 0.6630 - f1-score: 0.4750 - val_loss: 0.5644 - val_iou_score: 0.2372 - val_accuracy: 0.6493 - val_f1-score: 0.3605
# Epoch 476/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5056 - iou_score: 0.3051 - accuracy: 0.6557 - f1-score: 0.4171
# Epoch 00476: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.4354 - iou_score: 0.3609 - accuracy: 0.6587 - f1-score: 0.4648 - val_loss: 0.5619 - val_iou_score: 0.2358 - val_accuracy: 0.6486 - val_f1-score: 0.3863
# Epoch 477/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3662 - iou_score: 0.4053 - accuracy: 0.6628 - f1-score: 0.5039
# Epoch 00477: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.3806 - iou_score: 0.4107 - accuracy: 0.6623 - f1-score: 0.5082 - val_loss: 0.5643 - val_iou_score: 0.2383 - val_accuracy: 0.6477 - val_f1-score: 0.3773
# Epoch 478/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3654 - iou_score: 0.4454 - accuracy: 0.6602 - f1-score: 0.5256
# Epoch 00478: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.3641 - iou_score: 0.4397 - accuracy: 0.6613 - f1-score: 0.5234 - val_loss: 0.5678 - val_iou_score: 0.2386 - val_accuracy: 0.6470 - val_f1-score: 0.3661
# Epoch 479/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4547 - iou_score: 0.3285 - accuracy: 0.6567 - f1-score: 0.4392
# Epoch 00479: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.4135 - iou_score: 0.3652 - accuracy: 0.6577 - f1-score: 0.4703 - val_loss: 0.5385 - val_iou_score: -0.9597 - val_accuracy: 0.6500 - val_f1-score: 0.3564
# Epoch 480/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3757 - iou_score: 0.6062 - accuracy: 0.6634 - f1-score: 0.5947
# Epoch 00480: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.3806 - iou_score: 0.5026 - accuracy: 0.6634 - f1-score: 0.5470 - val_loss: 0.5224 - val_iou_score: 0.2431 - val_accuracy: 0.6515 - val_f1-score: 0.3541
# Epoch 481/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3671 - iou_score: 0.3856 - accuracy: 0.6625 - f1-score: 0.4866
# Epoch 00481: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.4066 - iou_score: 0.3136 - accuracy: 0.6656 - f1-score: 0.4202 - val_loss: 0.5173 - val_iou_score: 0.3246 - val_accuracy: 0.6527 - val_f1-score: 0.3624
# Epoch 482/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3773 - iou_score: 0.4048 - accuracy: 0.6612 - f1-score: 0.5037
# Epoch 00482: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.3920 - iou_score: 0.3851 - accuracy: 0.6614 - f1-score: 0.4872 - val_loss: 0.5214 - val_iou_score: 0.1790 - val_accuracy: 0.6526 - val_f1-score: 0.3909
# Epoch 483/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6751 - iou_score: 0.2171 - accuracy: 0.6595 - f1-score: 0.3250
# Epoch 00483: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.5445 - iou_score: 0.2786 - accuracy: 0.6602 - f1-score: 0.3866 - val_loss: 0.5331 - val_iou_score: 0.2488 - val_accuracy: 0.6517 - val_f1-score: -0.0193
# Epoch 484/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4135 - iou_score: 0.3519 - accuracy: 0.6607 - f1-score: 0.4590
# Epoch 00484: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 8s/step - loss: 0.4275 - iou_score: 0.3594 - accuracy: 0.6494 - f1-score: 0.4661 - val_loss: 0.5388 - val_iou_score: 0.2575 - val_accuracy: 0.6497 - val_f1-score: 0.4562
# Epoch 485/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5736 - iou_score: 0.2276 - accuracy: 0.6657 - f1-score: 0.3383
# Epoch 00485: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.5257 - iou_score: 0.2843 - accuracy: 0.6592 - f1-score: 0.3933 - val_loss: 0.5416 - val_iou_score: 0.2556 - val_accuracy: 0.6484 - val_f1-score: 0.3601
# Epoch 486/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4781 - iou_score: 0.3083 - accuracy: 0.6492 - f1-score: 0.4186
# Epoch 00486: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4582 - iou_score: 0.3656 - accuracy: 0.6489 - f1-score: 0.4633 - val_loss: 0.5414 - val_iou_score: 0.2503 - val_accuracy: 0.6473 - val_f1-score: 0.3661
# Epoch 487/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3552 - iou_score: 0.4139 - accuracy: 0.6538 - f1-score: 0.5106
# Epoch 00487: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4355 - iou_score: 0.3315 - accuracy: 0.6605 - f1-score: 0.4365 - val_loss: 0.5542 - val_iou_score: 0.2670 - val_accuracy: 0.6460 - val_f1-score: 0.4902
# Epoch 488/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5035 - iou_score: 0.3189 - accuracy: 0.6566 - f1-score: 0.4295
# Epoch 00488: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4787 - iou_score: 0.3215 - accuracy: 0.6611 - f1-score: 0.4316 - val_loss: 0.5807 - val_iou_score: 0.4227 - val_accuracy: 0.6436 - val_f1-score: 0.3657
# Epoch 489/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4258 - iou_score: 0.3275 - accuracy: 0.6541 - f1-score: 0.4392
# Epoch 00489: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4388 - iou_score: 0.3116 - accuracy: 0.6549 - f1-score: 0.4241 - val_loss: 0.5985 - val_iou_score: 0.5832 - val_accuracy: 0.6427 - val_f1-score: 0.2526
# Epoch 490/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4358 - iou_score: 0.3262 - accuracy: 0.6582 - f1-score: 0.4370
# Epoch 00490: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4423 - iou_score: 0.2841 - accuracy: 0.6644 - f1-score: 0.3957 - val_loss: 0.6276 - val_iou_score: 0.7139 - val_accuracy: 0.6409 - val_f1-score: 0.3120
# Epoch 491/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3979 - iou_score: 0.3587 - accuracy: 0.6573 - f1-score: 0.4619
# Epoch 00491: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4359 - iou_score: 0.2954 - accuracy: 0.6644 - f1-score: 0.4027 - val_loss: 0.6087 - val_iou_score: 3.0647 - val_accuracy: 0.6416 - val_f1-score: 0.3508
# Epoch 492/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4218 - iou_score: 0.2830 - accuracy: 0.6540 - f1-score: 0.3970
# Epoch 00492: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4360 - iou_score: 0.2910 - accuracy: 0.6530 - f1-score: 0.4045 - val_loss: 0.5580 - val_iou_score: 0.6627 - val_accuracy: 0.6427 - val_f1-score: 0.5102
# Epoch 493/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6419 - iou_score: 0.2330 - accuracy: 0.6597 - f1-score: 0.3400
# Epoch 00493: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.5243 - iou_score: 0.2308 - accuracy: 0.6686 - f1-score: 0.3402 - val_loss: 0.5503 - val_iou_score: 0.2244 - val_accuracy: 0.6419 - val_f1-score: 0.2832
# Epoch 494/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4810 - iou_score: 0.2465 - accuracy: 0.6547 - f1-score: 0.3593
# Epoch 00494: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4753 - iou_score: 0.2552 - accuracy: 0.6561 - f1-score: 0.3672 - val_loss: 0.5386 - val_iou_score: -0.0190 - val_accuracy: 0.6414 - val_f1-score: 0.4474
# Epoch 495/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4850 - iou_score: 0.2467 - accuracy: 0.6552 - f1-score: 0.3588
# Epoch 00495: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4875 - iou_score: 0.2346 - accuracy: 0.6544 - f1-score: 0.3462 - val_loss: 0.5130 - val_iou_score: 0.5583 - val_accuracy: 0.6426 - val_f1-score: 0.3292
# Epoch 496/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6118 - iou_score: 0.2044 - accuracy: 0.6496 - f1-score: 0.3119
# Epoch 00496: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.5703 - iou_score: 0.2243 - accuracy: 0.6519 - f1-score: 0.3346 - val_loss: 0.5018 - val_iou_score: 0.3361 - val_accuracy: 0.6437 - val_f1-score: 0.3308
# Epoch 497/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4640 - iou_score: 0.2636 - accuracy: 0.6550 - f1-score: 0.3744
# Epoch 00497: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4661 - iou_score: 0.2721 - accuracy: 0.6579 - f1-score: 0.3828 - val_loss: 0.5065 - val_iou_score: 0.2297 - val_accuracy: 0.6435 - val_f1-score: 0.2918
# Epoch 498/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4567 - iou_score: 0.2894 - accuracy: 0.6593 - f1-score: 0.3998
# Epoch 00498: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.4332 - iou_score: 0.3031 - accuracy: 0.6586 - f1-score: 0.4113 - val_loss: 0.5170 - val_iou_score: 0.2456 - val_accuracy: 0.6424 - val_f1-score: 0.3533
# Epoch 499/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4371 - iou_score: 0.3041 - accuracy: 0.6509 - f1-score: 0.4133
# Epoch 00499: loss did not improve from 0.33388
# 2/2 [==============================] - 15s 7s/step - loss: 0.4168 - iou_score: 0.3179 - accuracy: 0.6542 - f1-score: 0.4262 - val_loss: 0.5286 - val_iou_score: 0.2303 - val_accuracy: 0.6413 - val_f1-score: 0.3529
# Epoch 500/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3693 - iou_score: 0.3581 - accuracy: 0.6584 - f1-score: 0.4650
# Epoch 00500: loss did not improve from 0.33388
# 2/2 [==============================] - 14s 7s/step - loss: 0.3721 - iou_score: 0.3641 - accuracy: 0.6584 - f1-score: 0.4703 - val_loss: 0.5412 - val_iou_score: 0.2340 - val_accuracy: 0.6403 - val_f1-score: 0.3868

# %%
Model_.save(model_path+'model_TL_UNET.h5')

# %%
Model_.load_weights(model_path+'model_TL_UNET.h5')

# %%
Model_.metrics_names
# Out:
# ['loss', 'iou_score', 'accuracy', 'f1-score']

# %% [raw]
# TRAINING CURVES

# %%
# Plot training & validation loss values
plt.figure(figsize=(30, 5))
plt.subplot(122)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Plot training & validation F1 score values
plt.figure(figsize=(30, 5))
plt.subplot(122)
plt.plot(results.history['f1-score'])
plt.plot(results.history['val_f1-score'])
plt.title('Model F1-score')
plt.ylabel('f1-score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(30, 5))
plt.subplot(122)
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [raw]
# MODEL EVALUATION

# %%
evaluation_score = Model_.evaluate(GenerateInputs(X_test, y_test))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
#     210/Unknown - 15s 73ms/step - loss: 0.5412 - iou_score: 0.2340 - accuracy: 0.6403 - f1-score: 0.3868

# %% [raw]
# Visualization of Results on Validation Data

# %%
def ExtractData(path):
    SourceImg = sorted(os.listdir(path+'valid_img'))
    TargetImg = sorted(os.listdir(path+'valid_mask'))
   
    X_=[]
    y_=[]
    count=0
    for i in range(len(SourceImg)):
        if count<2165:
            count=count+1
            img_1 = cv2.imread(path+'valid_img/'+SourceImg[i])
            img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
            img_1 = cv2.resize(img_1,(500,500))
            img_1 = img_1/255.0
            X_.append(img_1)
            img_2 = cv2.imread(path+'valid_mask/'+TargetImg[i])
            img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
            img_2 = cv2.resize(img_2,(500,500))
            img_2 = img_2/255.0
            y_.append(img_2)
    X_ = np.array(X_)
    y_ = np.array(y_)
    
    return X_,y_

# %%
valid_img,valid_mask = ExtractData(path)

# %%
valid_img = valid_img.astype(np.float32)
valid_mask = valid_mask.astype(np.float32)

# %%
valid_evaluation_score = Model_.evaluate(GenerateInputs(valid_img, valid_mask))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
#      32/Unknown - 2s 73ms/step - loss: 0.5209 - iou_score: 0.2322 - accuracy: 0.6393 - f1-score: 0.3382

# %%
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
image_0 = cv2.imread(path+"valid_img/bob_700.jpg")  
image_0 = cv2.cvtColor(image_0, cv2.COLOR_BGR2RGB)
image_0 = cv2.resize(image_0, (710,470))
plt.title("Actual Image",fontsize=20)
plt.imshow(image_0)
image_0 = cv2.resize(image_0,(500,500))
image_0 = image_0.reshape(1,500,500,3)
prediction_0 = Model_.predict(image_0)
pred_0 = prediction_0.reshape(500,500,3)
pred_0 = cv2.resize(pred_0,(710,470))
plt.subplot(5,5,1+1)
plt.title("Segmented Image (prediction)",fontsize=20)
plt.imshow(pred_0, cmap='seismic')
plt.subplot(5,5,1+2)
img_g0 = cv2.imread(path+"valid_mask/bob_700.png")  
img_g0 = cv2.cvtColor(img_g0, cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img_g0,(710,470), 3)
plt.title("Mask",fontsize=20)
plt.imshow(img2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
image_0 = cv2.imread(path+"valid_img/cod_1120.jpg")  
image_0 = cv2.cvtColor(image_0, cv2.COLOR_BGR2RGB)
image_0 = cv2.resize(image_0, (710,470))
plt.title("Actual Image",fontsize=20)
plt.imshow(image_0)
image_0 = cv2.resize(image_0,(500,500))
image_0 = image_0.reshape(1,500,500,3)
prediction_0 = Model_.predict(image_0)
pred_0 = prediction_0.reshape(500,500,3)
pred_0 = cv2.resize(pred_0,(710,470))
plt.subplot(5,5,1+1)
plt.title("Segmented Image (prediction)",fontsize=20)
plt.imshow(pred_0, cmap='seismic')
plt.subplot(5,5,1+2)
img_g0 = cv2.imread(path+"valid_mask/cod_1120.png")  
img_g0 = cv2.cvtColor(img_g0, cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img_g0,(710,470), 3)
plt.title("Mask",fontsize=20)
plt.imshow(img2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
image_0 = cv2.imread(path+"valid_img/coastline (73).jpg")  
image_0 = cv2.cvtColor(image_0, cv2.COLOR_BGR2RGB)
image_0 = cv2.resize(image_0, (710,470))
plt.title("Actual Image",fontsize=20)
plt.imshow(image_0)
image_0 = cv2.resize(image_0,(500,500))
image_0 = image_0.reshape(1,500,500,3)
prediction_0 = Model_.predict(image_0)
pred_0 = prediction_0.reshape(500,500,3)
pred_0 = cv2.resize(pred_0,(710,470))
plt.subplot(5,5,1+1)
plt.title("Segmented Image (prediction)",fontsize=20)
plt.imshow(pred_0, cmap='RdGy')
plt.subplot(5,5,1+2)
img_g0 = cv2.imread(path+"valid_mask/coastline (73).png")  
img_g0 = cv2.cvtColor(img_g0, cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img_g0,(710,470), 3)
plt.title("Mask",fontsize=20)
plt.imshow(img2, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
preds_val = Model_.predict(valid_img[int(valid_img.shape[0]*0.9):], verbose=1)
# Out:
# 4/4 [==============================] - 6s 1s/sample

# %%
ix = random.randint(3, len(preds_val))
plt.imshow(valid_img[int(valid_img.shape[0]*0.9):][ix])
plt.title("Actual Image",fontsize=20)
plt.show()
plt.imshow(np.squeeze(valid_mask[int(valid_mask.shape[0]*0.9):][ix]))
plt.title("Mask",fontsize=20)
plt.show()
plt.imshow(np.squeeze(preds_val[ix]))
plt.title("Predicted_Segmentation_Mask",fontsize=20)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
preds_val2 = Model_.predict(valid_img[int(valid_img.shape[0]*0.9):], verbose=1)
# Out:
# 4/4 [==============================] - 0s 70ms/sample

# %%
ix2 = random.randint(0, len(preds_val2))
plt.imshow(valid_img[int(valid_img.shape[0]*0.9):][ix2])
plt.title("Actual Image",fontsize=20)
plt.show()
plt.imshow(np.squeeze(valid_mask[int(valid_mask.shape[0]*0.9):][ix2]))
plt.title("Mask",fontsize=20)
plt.show()
plt.imshow(np.squeeze(preds_val2[ix2]))
plt.title("Predicted_Segmentation_Mask",fontsize=20)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#valid_img[0] NOTE images are dtype=float32, not uint8

# %%
def ExtractData(path):
    SourceImg = sorted(os.listdir(path+'test_img'))
    TargetImg = sorted(os.listdir(path+'test_mask'))
   
    X_=[]
    y_=[]
    count=0
    for i in range(len(SourceImg)):
        if count<2165:
            count=count+1
            img_1 = cv2.imread(path+'test_img/'+SourceImg[i])
            img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
            img_1 = cv2.resize(img_1,(500,500))
            img_1 = img_1/255.0
            X_.append(img_1)
            img_2 = cv2.imread(path+'test_mask/'+TargetImg[i])
            img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
            img_2 = cv2.resize(img_2,(500,500))
            img_2 = img_2/255.0
            y_.append(img_2)
    X_ = np.array(X_)
    y_ = np.array(y_)
    
    return X_,y_

# %%
test_img, test_mask = ExtractData(path)

# %%
test_img = test_img.astype(np.float32)
test_mask = test_mask.astype(np.float32)

# %%
test_evaluation_score = Model_.evaluate(GenerateInputs(test_img, test_mask))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
#      32/Unknown - 2s 70ms/step - loss: 0.5380 - iou_score: 0.2013 - accuracy: 0.6382 - f1-score: 0.5084

# %%
preds_test = Model_.predict(test_img[int(test_img.shape[0]*0.9):], verbose=1)
# Out:
# 4/4 [==============================] - 0s 66ms/sample

# %%
ix = random.randint(1, len(preds_test))
plt.imshow(test_img[int(test_img.shape[0]*0.9):][ix])
plt.title("Actual Image",fontsize=20)
plt.show()
plt.imshow(np.squeeze(test_mask[int(test_mask.shape[0]*0.9):][ix]))
plt.title("Mask",fontsize=20)
plt.show()
plt.imshow(np.squeeze(preds_test[ix]))
#plt.imshow(preds_test[ix].contour(preds_test[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5]))
plt.title("Predicted_Segmentation_Mask",fontsize=20)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
valid_img.shape

# %%
test_img.shape

# %%
# test_img[int(test_img.shape[0]*0.9):]

# %%
# test_img*0.9

# %%
# CODE SOURCES: 
#         https://www.kaggle.com/basu369victor/transferlearning-and-unet-to-segment-rocks-on-moon
#         https://github.com/bnsreenu/python_for_microscopists/blob/master/076-077-078-Unet_nuclei_tutorial.py
#         https://github.com/qubvel/segmentation_models
